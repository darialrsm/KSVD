# %% [markdown]
# <a href="https://colab.research.google.com/github/darialrsm/KSVD/blob/main/%D0%A5%D0%B0%D1%85%D0%BB%D1%94%D0%B2%D0%B0_%D0%9A%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8C%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Підсумкова контрольна робота КСВД**

# %% [markdown]
# # Завдання 1
# Загрузити датасет Global YouTube Statistics 2023

# %% [markdown]
# 1.Прочитайте CSV файл

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-804e1e25-e08d-4b0a-9011-8335190542ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-804e1e25-e08d-4b0a-9011-8335190542ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding='latin1')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# 2. Виведіть перші п'ять рядків

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# 3. Виведіть розміри датасету, перевірте наявність пропусків, дублікатів.

# %%
df.shape
# Out:
# (995, 28)

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4.Якщо є пропуски, замінить тип даних на float і середнє значення за стовпцем

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
        try:
            df[col] = df[col].astype(float)
            df[col].fillna(df[col].mean(), inplace=True)
        except ValueError:
            continue

# %% [markdown]
# 5. Ще раз перевірте кількість пропусків.

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             0
# country_rank                                 0
# channel_type_rank                            0
# video_views_for_the_last_30_days             0
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days                 0
# created_year                                 0
# ...

# %%
for col in ['created_month', 'category', 'Country', 'Abbreviation', 'channel_type']:
    if col in df.columns and df[col].isnull().sum() > 0:
        mode_val = df[col].mode()[0]
        df[col].fillna(mode_val, inplace=True)
# Out:
# <ipython-input-12-323844a1a5a8>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mode_val, inplace=True)

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %% [markdown]
# 6. Перевірте, скільки унікальних країн представлено у колонці "Country"

# %%
df['Country'].nunique()
# Out:
# 49

# %% [markdown]
# 7. Побудуйте діаграму розподілу переглядів (використовуйте kind='hist'):

# %%
df['video views'].plot(kind='hist', bins=30, color='skyblue', edgecolor='black', figsize=(8, 5))
plt.title('Розподіл переглядів')
plt.xlabel('Кількість переглядів')
plt.ylabel('Кількість каналів')
plt.grid(True)
plt.show()

# %% [markdown]
# 8. Визначте максимальну, мінімальну, середню кількість переглядів
# (використовуйте методи max, min, mean)

# %%
df['video views'].min()
# Out:
# 0.0

# %%
df['video views'].max()
# Out:
# 228000000000.0

# %%
df['video views'].mean()
# Out:
# np.float64(11039537052.03819)

# %% [markdown]
# 9. Знайдіть країну, де найбільше відео було завантажено на YouTube

# %%
country_with_most_videos = df.groupby('Country')['uploads'].sum().idxmax()
country_with_most_videos
# Out:
# 'India'

# %% [markdown]
# 10. Знайдіть відео (виведіть його назву) з найбільшою та найменшою
# кількістю завантажень uploads.

# %%
max_upload = df[df['uploads'] == df['uploads'].max()]['Title'].values[0]
max_upload
# Out:
# 'ABP NEWS'

# %%
min_upload = df[df['uploads'] == df['uploads'].min()]['Title'].values[0]
min_upload
# Out:
# 'Music'

# %% [markdown]
# # **Завдання 2**
# # Зчитати архів Customer Shopping Trends Dataset

# %% [markdown]
# Прочитайте CSV файл

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a12f9533-3069-4577-9aec-bf6031da8c8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a12f9533-3069-4577-9aec-bf6031da8c8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_shopping = pd.read_csv('shopping_trends.csv', encoding='latin1')
df_shopping
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# Перевірте розмір таблиці, наявність пропусків, тип стовпців.

# %%
df_shopping.shape
# Out:
# (3900, 19)

# %%
df_shopping.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df_shopping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# Перейменуйте назви стовпців: Змініть прописні букви на строчні (маленькі) та пробіл на підкреслення.

# %%
new_columns = {col: col.lower().replace(' ', '_') for col in df_shopping.columns}
df_shopping.rename(columns=new_columns, inplace=True)

# %%
df_shopping
# Out:
#       customer_id  age  gender item_purchased     category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       purchase_amount_(usd)       location size      color  season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# # Побудуйте графіки з використанням бібліотеки seaborn

# %%
sns.set_style("whitegrid")

# %% [markdown]
# 1. Гістограма віку (age):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_shopping, x='age', bins=20, kde=True, color='skyblue')
plt.title('Розподіл віку клієнтів', fontsize=16)
plt.xlabel('Вік', fontsize=12)
plt.ylabel('Кількість клієнтів', fontsize=12)
plt.show()

# %% [markdown]
# 2.Порівняння розподілу покупок за статтею (item_purchased):

# %%
plt.figure(figsize=(14, 7))
sns.countplot(data=df_shopping, y='item_purchased', order=df_shopping['item_purchased'].value_counts().index, palette='viridis')
plt.title('Найчастіше куплені товари', fontsize=16)
plt.xlabel('Кількість покупок', fontsize=12)
plt.ylabel('Товар', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-44-8887fb790341>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_shopping, y='item_purchased', order=df_shopping['item_purchased'].value_counts().index, palette='viridis')

# %% [markdown]
# 3.Залежність між віком та сумою покупок (purchase_amount):

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df_shopping, x='age', y='purchase_amount_(usd)', alpha=0.6, color='purple')
plt.title('Залежність між віком та сумою покупок', fontsize=16)
plt.xlabel('Вік', fontsize=12)
plt.ylabel('Сума покупок (USD)', fontsize=12)
plt.show()

# %% [markdown]
# 4.Графік розподілу оцінок товарів (review_rating):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_shopping, x='review_rating', bins=10, kde=True, color='lightcoral')
plt.title('Розподіл оцінок товарів', fontsize=16)
plt.xlabel('Оцінка товару', fontsize=12)
plt.ylabel('Частота', fontsize=12)
plt.show()

# %% [markdown]
# 5.Категоріальна діаграма для статі (gender):

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df_shopping, x='gender', palette='pastel')
plt.title('Розподіл покупців за статтю', fontsize=16)
plt.xlabel('Стать', fontsize=12)
plt.ylabel('Кількість покупців', fontsize=12)
plt.show()
# Out:
# <ipython-input-47-97b4a371e59c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_shopping, x='gender', palette='pastel')

# %% [markdown]
# 6.Залежність між рейтингом і сумою покупок (review_rating і
# purchase_amount)

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df_shopping, x='review_rating', y='purchase_amount_(usd)', hue='gender', alpha=0.7, palette='deep')
plt.title('Залежність між рейтингом товару та сумою покупок', fontsize=16)
plt.xlabel('Оцінка товару', fontsize=12)
plt.ylabel('Сума покупок (USD)', fontsize=12)
plt.show()

# %% [markdown]
# # **Завдання 3**

# %%
import altair as alt
import pandas as pd
import plotly.express as px
from vega_datasets import data

# %% [markdown]
# 1. Створіть горизонтальну діаграму з мітками на основі даних про
# врожайність пшениці (data.wheat()) за допомогою бібліотеки Altair.
# Задайте вісь x для врожайності пшениці, вісь y для років, а текстові
# мітки відображайте значення врожайності пшениці на відповідних
# роках.

# %%
wheat = data.wheat()
chart = alt.Chart(wheat).mark_bar().encode(
    x='wheat:Q',
    y=alt.Y('year:O', sort='-x')  # Роки по осі Y, в порядку спадання
).properties(
    title='Врожайність пшениці по роках'
)


text = alt.Chart(wheat).mark_text(
    align='left',
    baseline='middle',
    dx=3  # Зміщення тексту від краю стовпця
).encode(
    x='wheat:Q',
    y=alt.Y('year:O', sort='-x'),
    text='wheat:Q'
)

(chart + text).configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# 2. Створіть багатошарову діаграму на основі даних про виробництво
# електроенергії в штаті Айова (data.iowa_electricity()) за допомогою
# бібліотеки Altair . Вісь x представляє роки, вісь y відображає чисте
# виробництво електроенергії (net_generation), а кожен шар діаграми
# позначає різні джерела енергії (source). Встановіть прозорість (opacity)
# для стовпців на рівні 0.7.

# %%
electricity = data.iowa_electricity()

chart = alt.Chart(electricity).mark_bar(opacity=0.7).encode(
    x='year:O',
    y='net_generation:Q',
    color='source:N'
).properties(
    title='Виробництво електроенергії в Айові за джерелами'
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# 3. Створіть графік за допомогою бібліотеки Plotly (scatter plot) для даних
# ірисів (iris dataset), де:
# Вісь X (x-axis) відповідає ширині чашелистика (sepal width).
# Вісь Y (y-axis) відповідає довжині чашелистика (sepal length).
# Кожен пункт на графіку має розмір, який залежить від довжини
# пелюстки (petal length).
# Кожен пункт на графіку має різний колір в залежності від виду
# (species).
# При наведенні на пункт повинні відображатися додаткові дані, такі як
# ширина пелюстки (petal width

# %%
df_iris = px.data.iris()

fig_iris = px.scatter(df_iris,
                      x="sepal_width",
                      y="sepal_length",
                      size="petal_length",
                      color="species",
                      hover_name="species",
                      hover_data=["petal_width", "petal_length", "sepal_width", "sepal_length"],
                      title="Розподіл ірисів за шириною/довжиною чашелистика",
                      labels={
                          "sepal_width": "Ширина чашелистика (см)",
                          "sepal_length": "Довжина чашелистика (см)",
                          "petal_length": "Довжина пелюстки (см)"
                      })

fig_iris.update_layout(
    xaxis_title="Ширина чашелистика (см)",
    yaxis_title="Довжина чашелистика (см)",
    title_x=0.5
)

fig_iris.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Висновок**
# Завдання 1 (YouTube Statistics 2023):Проведено первинний аналіз датасету: перевірка розмірів, пропусків, дублікатів.Оброблено пропуски (заміна на середнє). Побудовано гістограму переглядів, знайдено крайні значення.Визначено країну з найбільше відео та назви найпопулярніших/найменш популярних відео.
#
# Завдання 2 (Customer Shopping Trends): Підготовлено дані: перейменування стовпців, перевірка типів.Виконано візуалізацію трендів покупок за допомогою графіків Seaborn.
#
# Завдання 3 (Altair і Plotly): Altair: створено горизонтальну діаграму врожайності пшениці та багатошарову діаграму виробництва електроенергії. Plotly: побудовано інтерактивний scatter plot для ірисів із динамічним відображенням параметрів.
